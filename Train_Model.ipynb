# %% [markdown]
# ### Formal training the proposed Multitask Model

# %%
# !python pytorch/train.py wandb.note='formal latent8 mmoe8 5x5' exp.model_name=MultiTaskCNN dataset.run_all_folds=True
# Out:
# [W&B] GPU monitor devices: (unset) | policy=visible
# wandb: Currently logged in as: zhanh (zhanh-uwa). Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.3
# wandb: Run data is saved locally in /media/mengh/SharedData/zhanh/piano-dynamic-estimation/wandb/run-20250910_151651-n9k9l5r0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run formal latent8 mmoe8 5x5-sone-MultiTaskCNN-['dynamic', 'change_point', 'beat', 'downbeat']-fold0
# wandb: ⭐️ View project at https://wandb.ai/zhanh-uwa/2025_icassp
# wandb: 🚀 View run at https://wandb.ai/zhanh-uwa/2025_icassp/runs/n9k9l5r0
# ...
# Eval: 100%|█████████████████████████████████████| 20/20 [00:03<00:00,  5.36it/s]
# wandb:
# wandb:
# wandb: Run history:
# wandb:         beat_loss █▄▆▅▅▃▄▃▃▅▂▄▁▄▄▂▄▁▂▃▃▁▃▃▃▄▂▃▃▃▅▂▃▃▃▂▄▃▂▂
# ...

# %% [markdown]
# ### Training the Ablation Variants of the Proposed Multitask Model

# %%
# !python pytorch/train.py dataset.run_all_folds=True wandb.note='formal latent8 mmoe8 5x5' exp.model_name=MultiTaskCNN feature.audio_feature="logmel"
# !python pytorch/train.py dataset.run_all_folds=True wandb.note='ablation no_mmoe8 5x5' exp.model_name=MultiTaskCNN cnn.use_mmoe=False 
# !python pytorch/train.py dataset.run_all_folds=True wandb.note='ablation mmoe8 1x1' exp.model_name=MultiTaskCNN cnn.temporal_scale=[1,1]
# !python pytorch/train.py dataset.run_all_folds=True wandb.note='ablation mmoe8 5x5 no_augment' exp.model_name=MultiTaskCNN feature.segment_hop_seconds=60
# !python pytorch/train.py dataset.run_all_folds=True wandb.note='ablation mmoe8 5x5 30s' exp.model_name=MultiTaskCNN feature.segment_seconds=30

# %% [markdown]
# ### Training the Single-Task Models

# %%
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["dynamic"]      dataset.run_all_folds=True  feature.audio_feature="logmel" 
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["change_point"] dataset.run_all_folds=True  feature.audio_feature="logmel" 
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["beat"]         dataset.run_all_folds=True  feature.audio_feature="logmel" 
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["downbeat"]     dataset.run_all_folds=True  feature.audio_feature="logmel"

# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["dynamic"]      dataset.run_all_folds=True  feature.audio_feature="sone" 
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["change_point"] dataset.run_all_folds=True  feature.audio_feature="sone" 
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["beat"]         dataset.run_all_folds=True  feature.audio_feature="sone" 
# !python pytorch/train.py wandb.note='formal' exp.model_name=SingleCNN exp.targets=["downbeat"]     dataset.run_all_folds=True  feature.audio_feature="sone"
